# %%
import ISLP

ISLP.load_data("College")
# Out:
#     Private   Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  \
# 0       Yes   1660    1232     721         23         52         2885
# 1       Yes   2186    1924     512         16         29         2683
# 2       Yes   1428    1097     336         22         50         1036
# 3       Yes    417     349     137         60         89          510
# 4       Yes    193     146      55         16         44          249
# ..      ...    ...     ...     ...        ...        ...          ...
# 772      No   2197    1515     543          4         26         3089
# 773     Yes   1959    1805     695         24         47         2849
# 774     Yes   2097    1915     695         34         61         2793
# 775     Yes  10705    2453    1317         95         99         5217
# 776     Yes   2989    1855     691         28         63         2988
#
#      P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  Terminal  \
# ...

# %% [markdown]
# The following **College** data details information of 777 US colleges (see: <a href="https://hastie.su.domains/ISLP/ISLP_website.pdf">Introduction into Statistical Learning</a>). The Data contains the following columns:
#
# | Variable | Description |
# | --- | ----------- |
# | *Private*| Public/private indicator |
# | *Apps*| Number of applications received |
# | *Accept*| Number of applicants accepted |
# | *Enroll*| Number of new students enrolled |
# | *Top10perc*| New students from top 10 % of high school class |
# | *Top25perc*| New students from top 25 % of high school class |
# | *F.Undergrad*| Number of full-time undergraduates |
# | *P.Undergrad*| Number of part-time undergraduates |
# | *Outstate*| Out-of-state tuition |
# | *Room.Board*| Room and board costs |
# | *Books*| Estimated book costs |
# | *Personal*| Estimated personal spending |
# | *PhD*| Percent of faculty with Ph.D.s |
# | *Terminal*| Percent of faculty with terminal degree |
# | *S.F.Ratio*| Student/faculty ratio |
# | *perc.alumni*| Percent of alumni who donate |
# | *Expend*| Instructional expenditure per student |
# | *Grad.Rate*| Graduation rate |

# %% [markdown]
# Consider the following exercises:
# * For ease of use, having "." in a columnname is not nice. Rename all columns with a "." in their columnname by exchanging it with a "_". (Hint: DataFrame.rename)
# * Create a new variable "Acceptance_Rate" that calculates the number of students accepted in % based on the number of applications and add it to the dataframe.
# * Sort the Dataframe by the variables "Private" and "Apps", consecutively in an ascending manner.
# * Create a new binary qualitative variable, called "Elite", by binning the "Top10perc" variable into two groups based on whether or not the proportion of students coming from the top 10% of their high school classes exceeds 50%. (Hint: pd.cut function)
# * Use the describe() method of to produce a numerical summary of the variables in the data set.
# * Group the data by the variable "Private" and investigate the mean for the variables "Acceptance_Rate", "Room_Board", "Books", "Phd" and "Graduation_Rate". What can you see?
# * Group the data by "Private" AND "Elite" and consider the same variables. Can you see a difference?

# %%
import ISLP
colleges = ISLP.load_data("College")

# %%
# For ease of use, having "." in a columnname is not nice. Rename all columns with a "." in their columnname by exchanging it with a "_". (Hint: DataFrame.rename)
import pandas as pd


colleges_pd = pd.DataFrame(colleges)

for column in colleges_pd.columns:
    new_col = column.replace('.', '_')
    # https://stackoverflow.com/a/66607872
    colleges_pd.columns = colleges_pd.columns.str.replace(column, new_col, regex=False)

print(colleges_pd)
# Out:
#     Private   Apps  Accept  Enroll  Top10perc  Top25perc  F_Undergrad  \
# 0       Yes   1660    1232     721         23         52         2885
# 1       Yes   2186    1924     512         16         29         2683
# 2       Yes   1428    1097     336         22         50         1036
# 3       Yes    417     349     137         60         89          510
# 4       Yes    193     146      55         16         44          249
# ..      ...    ...     ...     ...        ...        ...          ...
# 772      No   2197    1515     543          4         26         3089
# 773     Yes   1959    1805     695         24         47         2849
# 774     Yes   2097    1915     695         34         61         2793
# 775     Yes  10705    2453    1317         95         99         5217
# 776     Yes   2989    1855     691         28         63         2988
#
#      P_Undergrad  Outstate  Room_Board  Books  Personal  PhD  Terminal  \
# ...

# %%
# Create a new variable "Acceptance_Rate" that calculates the number of students accepted in % based on the number of applications and add it to the dataframe.

colleges_pd["Acceptance_Rate"] = (colleges_pd["Accept"]/colleges_pd["Apps"]*100)
print(colleges_pd)
# Out:
#     Private   Apps  Accept  Enroll  Top10perc  Top25perc  F_Undergrad  \
# 0       Yes   1660    1232     721         23         52         2885
# 1       Yes   2186    1924     512         16         29         2683
# 2       Yes   1428    1097     336         22         50         1036
# 3       Yes    417     349     137         60         89          510
# 4       Yes    193     146      55         16         44          249
# ..      ...    ...     ...     ...        ...        ...          ...
# 772      No   2197    1515     543          4         26         3089
# 773     Yes   1959    1805     695         24         47         2849
# 774     Yes   2097    1915     695         34         61         2793
# 775     Yes  10705    2453    1317         95         99         5217
# 776     Yes   2989    1855     691         28         63         2988
#
#      P_Undergrad  Outstate  Room_Board  Books  Personal  PhD  Terminal  \
# ...

# %%
# Sort the Dataframe by the variables "Private" and "Apps", consecutively in an ascending manner.

colleges_pd = colleges_pd.sort_values(by = ['Private', 'Apps'], ascending=[True, True])
print(colleges_pd)
# Out:
#     Private   Apps  Accept  Enroll  Top10perc  Top25perc  F_Undergrad  \
# 355      No    233     233     153          5         12          658
# 672      No    285     280     208         21         43         1140
# 706      No    368     344     212          5         27          863
# 165      No    434     412     319         10         30         1376
# 630      No    441     369     172         17         45          633
# ..      ...    ...     ...     ...        ...        ...          ...
# 407     Yes  13594    7244    2505         70         86        12408
# 174     Yes  13789    3893    1583         90         98         6188
# 250     Yes  13865    2165    1606         90        100         6862
# 614     Yes  14446   10516    3252         22         57        14130
# 59      Yes  20192   13007    3810         45         80        14971
#
#      P_Undergrad  Outstate  Room_Board  Books  Personal  PhD  Terminal  \
# ...

# %%
# Create a new binary qualitative variable, called "Elite", by binning the "Top10perc" variable into two groups based on whether or not the proportion of students coming from
# the top 10% of their high school classes exceeds 50%. (Hint: pd.cut function)

# https://stackoverflow.com/a/54343112

bins = [0, 51, 100]
labels = ["No", "Yes"]
colleges_pd['Elite'] = pd.cut(colleges_pd['Top10perc'], bins=bins, labels=labels)
colleges_pd.tail()
# Out:
#     Private   Apps  Accept  Enroll  Top10perc  Top25perc  F_Undergrad  \
# 772      No   2197    1515     543          4         26         3089
# 773     Yes   1959    1805     695         24         47         2849
# 774     Yes   2097    1915     695         34         61         2793
# 775     Yes  10705    2453    1317         95         99         5217
# 776     Yes   2989    1855     691         28         63         2988
#
#      P_Undergrad  Outstate  Room_Board  Books  Personal  PhD  Terminal  \
# 772         2029      6797        3900    500      1200   60        60
# 773         1107     11520        4960    600      1250   73        75
# 774          166      6900        4200    617       781   67        75
# 775           83     19840        6510    630      2115   96        96
# 776         1726      4990        3560    500      1250   75        75
#
#      S_F_Ratio  perc_alumni  Expend  Grad_Rate  Acceptance_Rate Elite
# ...

# %%
# Use the describe() method of to produce a numerical summary of the variables in the data set.

colleges_pd.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F_Undergrad   P_Undergrad      Outstate   Room_Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
# Group the data by the variable "Private" and investigate the mean for the variables "Acceptance_Rate", "Room_Board", "Books", "Phd" and "Graduation_Rate". What can you see?

ar = colleges_pd.groupby(['Private'])["Acceptance_Rate"].mean()
rb = colleges_pd.groupby(['Private'])["Room_Board"].mean()
b = colleges_pd.groupby(['Private'])["Books"].mean()
phd = colleges_pd.groupby(['Private'])["PhD"].mean()
gr = colleges_pd.groupby(['Private'])["Grad_Rate"].mean()
print(ar, rb, b, phd, gr)
# Out:
# Private
# No     72.653048
# Yes    75.458118
# Name: Acceptance_Rate, dtype: float64 Private
# No     3748.240566
# Yes    4586.143363
# Name: Room_Board, dtype: float64 Private
# No     554.377358
# Yes    547.506195
# Name: Books, dtype: float64 Private
# No     76.834906
# Yes    71.093805
# Name: PhD, dtype: float64 Private
# No     56.042453
# Yes    68.998230
# Name: Grad_Rate, dtype: float64

# %%
# Group the data by "Private" AND "Elite" and consider the same variables. Can you see a difference?

ar = colleges_pd.groupby(['Private', 'Elite'])["Acceptance_Rate"].mean()
rb = colleges_pd.groupby(['Private', 'Elite'])["Room_Board"].mean()
b = colleges_pd.groupby(['Private', 'Elite'])["Books"].mean()
phd = colleges_pd.groupby(['Private', 'Elite'])["PhD"].mean()
gr = colleges_pd.groupby(['Private', 'Elite'])["Grad_Rate"].mean()
print(ar, rb, b, phd, gr)
# Out:
# Private  Elite
# No       No       73.858531
#          Yes      54.199882
# Yes      No       78.092048
#          Yes      53.289211
# Name: Acceptance_Rate, dtype: float64 Private  Elite
# No       No       3696.376884
#          Yes      4542.153846
# Yes      No       4471.958416
#          Yes      5547.200000
# Name: Room_Board, dtype: float64 Private  Elite
# No       No       550.005025
#          Yes      621.307692
# Yes      No       542.237624
#          Yes      591.850000
# Name: Books, dtype: float64 Private  Elite
# No       No       76.175879
#          Yes      86.923077
# Yes      No       68.780198
#          Yes      90.566667
# Name: PhD, dtype: float64 Private  Elite
# No       No       54.643216
#          Yes      77.461538
# Yes      No       67.025743
#          Yes      85.600000
# Name: Grad_Rate, dtype: float64
